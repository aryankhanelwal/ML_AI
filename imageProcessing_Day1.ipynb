# %%
import skimage as ski
import matplotlib.pyplot as plt
import cv2
import numpy

# %% [markdown]
# # Image processing - enhancement or information extraction

# %%
# Digital image is unsigned int of 8 bit.
# Image types :-
# 1 True color image
# RGB , CMYK , HSV , BGR. we the help of this we can create true color image
# 2 Grayscale
# 3 BInary
#

# %%
img = cv2.imread('firstimg.jpg')
cv2.imshow('Hello', img)
cv2.waitKey(100)
cv2.destroyAllWindows()

# %%
img1 = plt.imread('firstimg.jpg')
plt.imshow(img1)

# %% [markdown]
# # Day 11

# %%
vid = cv2.VideoCapture(0)

# %%
vid.isOpened()
# Out:
# True

# %%
k = vid.read()

# %%
type(k), len(k)
# Out:
# (tuple, 2)

# %%
flag, img = vid.read()  # flag will take one value and img will take another,BGR format

# %%
if flag:
    plt.imshow(img[:, :, ::-1])

# %%
fd = cv2.Cas

vid = cv2.VideoCapture(0)
while True:
    flag, img = vid.read()
    if flag:
        # plt.imshow(img[:,:,::-1])
        #processing code

        #img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        #th, img_bw = cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV) #by thresh we ca convert all pixels like all the pixel greater than 100 will became white and all other will turn black
       x,y,w,z = (250,0,200,200)
       img_Crop = img[y:y+z,x:x+w,:]

       cv2.rectangle(img,pt1 = (x,y),pt2 = (x+w,y+z),color =(0,0,255) ,thickness=8)

       cv2.imshow('home', img)
       key = cv2.waitKey(1)
       if key == ord('a'): #ord is used to find ascii code
            break
    else:
        break
vid.release()
cv2.destroyAllWindows()
